# %%
###1.Reading the Data
 ##Reading the housing dataset which consists of 2000 rows and 16 columns

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
housing_df=pd.read_csv("Downloads\\housing.csv")
housing_df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
#2 Creating Categorical and Numerical  Columns

# %%
categ_col=housing_df.select_dtypes(include=object).columns
num_cols=housing_df.select_dtypes(exclude=object).columns
categ_col,num_cols
# Out:
# (Index(['ocean_proximity'], dtype='object'),
#  Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#         'total_bedrooms', 'population', 'households', 'median_income',
#         'median_house_value'],
#        dtype='object'))

# %%
##3 Data Quick Checks  shape gives the dataset size and structure. like rows and columns

# %%
housing_df.size
# Out:
# 206400

# %%
housing_df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# ocean_proximity        object
# dtype: object

# %%
housing_df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
housing_df.tail()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# ...

# %%
housing_df.shape
# Out:
# (20640, 10)

# %%
housing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
# isnull() is used to detect missing values in the dataset.
housing_df.isnull()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0          False     False               False        False           False
# 1          False     False               False        False           False
# 2          False     False               False        False           False
# 3          False     False               False        False           False
# 4          False     False               False        False           False
# ...          ...       ...                 ...          ...             ...
# 20635      False     False               False        False           False
# 20636      False     False               False        False           False
# 20637      False     False               False        False           False
# 20638      False     False               False        False           False
# 20639      False     False               False        False           False
#
# ...

# %%
# isnull.sum() isnull.sum() gives the number of missing values in each column

# %%
housing_df.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
expensive_by_location = housing_df.groupby('ocean_proximity')['median_house_value'].mean().sort_values(ascending=False)
print(expensive_by_location)
# Out:
# ocean_proximity
# ISLAND        380440.000000
# NEAR BAY      259212.311790
# NEAR OCEAN    249433.977427
# <1H OCEAN     240084.285464
# INLAND        124805.392001
# Name: median_house_value, dtype: float64

# %%
#Find expensive houses
median_price = housing_df['median_house_value'].median()

housing_df['price_category'] = housing_df['median_house_value'].apply(
    lambda price: 'Expensive' if price > median_price else 'Cheap'
)

print(housing_df[['median_house_value', 'price_category']].head())
# Out:
#    median_house_value price_category
# 0            452600.0      Expensive
# 1            358500.0      Expensive
# 2            352100.0      Expensive
# 3            341300.0      Expensive
# 4            342200.0      Expensive

# %%
###Average houe price by location using barchart
import matplotlib.pyplot as plt

# Group by ocean proximity and calculate average house value
avg_price_by_location = housing_df.groupby('ocean_proximity')['median_house_value'].mean().sort_values()

# Create a figure of appropriate size
plt.figure(figsize=(10, 6))  

# Plot the vertical bar chart
plt.bar(avg_price_by_location.index, avg_price_by_location.values, color='pink')

# Add labels and title
plt.xlabel('Ocean Proximity')
plt.ylabel('Average House Value')
plt.title('Average House Price by Location')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
##Using scatterplots,using lambdas,dictionary which saves expensive and cheap values.
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you already have the DataFrame housing_df

# 1. Label each house as 'Cheap' or 'Expensive' based on median price
median_price = housing_df['median_house_value'].median()

housing_df['price_category'] = housing_df['median_house_value'].apply(
    lambda price: 'Expensive' if price > median_price else 'Cheap'
)

# 2. Separate data into cheap and expensive using keys (labels)
category_groups = {
    key: housing_df[housing_df['price_category'] == key]
    for key in housing_df['price_category'].unique()
}

# 3. Plot scatter plots for each category
plt.figure(figsize=(10, 6))

# Use longitude and latitude for plotting locations
colors = {'Cheap': 'green', 'Expensive': 'red'}

for category, subset in category_groups.items():
    plt.scatter(
        subset['longitude'],
        subset['latitude'],
        
        alpha=0.5,
        label=category,
        c=colors[category]
    )

# 4. Add labels, legend, and title
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Scatter Plot of Cheap vs Expensive Houses, ')
plt.legend()
plt.tight_layout()
plt.show()

# %%
#describe() gives the complete analysis of numerical columns in the datase
housing_df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
##Histogram of the age of houses can be find..FOr here age of the houses betwen 1 to 52.
age_data=housing_df['housing_median_age']
count,interval,bins=plt.hist(age_data)
plt.xlabel('age')
plt.ylabel('count')
plt.title('Age of houses')
# Out:
# Text(0.5, 1.0, 'Age of houses')
